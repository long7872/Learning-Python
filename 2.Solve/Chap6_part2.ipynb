# %% [markdown]
# Lab 6-1

# %%
# Server
# open("source/chap_6/6-1_server.py")

# Console:
# Wait from Client 

# Connected to address: ('127.0.0.1', 62341)
# ====================================
# Client
# open("source/chap_6/6-1_client.py")

# Console:
# Hi, Server: Hello
# Receive a Message from Client, That is: Hello. Good Bye, See you again

# %% [markdown]
# Lab 6-2

# %%
# Access to http://data.pr4e.org

import socket as sk
mysock = sk.socket(sk.AF_INET, sk.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)
while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Tue, 24 Feb 2026 13:46:28 GMT
# Server: Apache/2.4.52 (Ubuntu)
# Vary: Accept-Encoding
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Content-Length: 3143
# Connection: close
# Content-Type: text/html;charset=UTF-8
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <html>
#  <head>
#   <title>Index of /</title>
#  </head>
#  <body>
# <h1>Index of /</h1>
#   <table>
#    <tr><th valign="top"><img src="/icons/blank.gif" al
# t="[ICO]"></th><th><a href="?C=N;O=D">Name</a></th><th><a href="?C=M;O=A">Last modified</a></th><th><a href="?C=S;O=A">Size</a></th><th><a href="?C=D;O=A">Description</a></th></tr>
#    <tr><th colspan="5"><hr></th></tr>
# <tr><td valign="top"><img src="/icons/text.gif" alt="[TXT]"></td><td><a href="authors.txt">authors.txt</a></td><td align="right">2017-05-13 07:22  </td><td align="right">147 </td><td>&nbsp;</td></tr>
# ...

# %% [markdown]
# Lab 6-3

# %%
# Access to a text file  at http://data.pr4e.org/romeo.txt 

import socket as sk
mysock = sk.socket(sk.AF_INET, sk.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)
while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Tue, 24 Feb 2026 13:50:06 GMT
# Server: Apache/2.4.52 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already s
# ick and pale with grief

# %% [markdown]
# Lab 6-4

# %%
# Access to file

import urllib.request as urq
fhand = urq.urlopen('http://data.pr4e.org/romeo.txt')
for line in fhand:
    line = bytes(line)
    print(line.decode().strip())
print('='*60)
fhand = urq.urlopen('http://www.dr-chuck.com/page1.htm')
for line in fhand:
    line = bytes(line)
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief
# ...
# <h1>The First Page</h1>
# <p>
# If you like, you can switch to the
# <a href="http://www.dr-chuck.com/page2.htm">
# Second Page</a>.
# </p>

# %% [markdown]
# Lab 6-5

# %%
import urllib.request as urq
fhand = urq.urlopen('http://data.pr4e.org/romeo.txt')
dict_word = dict()

for line in fhand:
    line = bytes(line)
    word_in_line = line.decode().split()
    for word in word_in_line:
        dict_word[word] = dict_word.get(word, 0) + 1
print(dict_word)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %% [markdown]
# Lab 6-6

# %%
# import smtplib

# sender_email = 'long77872@gmail.com'
# password = '123456'
# receiver_email = 'longtmk.23itb@vku.udn.vn@gmail.com'
# text = "Hi, How are you?"
# connect = smtplib.SMTP_SSL('smtp.gmail.com', 465)
# connect.login(sender_email, password)
# connect.sendmail(sender_email, receiver_email, text)

# Cannot send email cuz less safe mode turn off pernamently

# %% [markdown]
# Lab 6-7

# %%
# Server
# open("source/chap_6/6-7_server.py")

# Console:
# Server is ready !!!
# Message of client: Hello, I'm Client 1
# Enter message to send client: Hi Client 1
# Shutdown Server? (y/n): n
# Message of client: Hello Server, I'm Client 2
# Enter message to send client: Yo Client 2
# Shutdown Server? (y/n): y
# ====================================
# Client 1
# open("source/chap_6/6-7_client1.py")

# Console:
# Client 1 send a message to server: Hello, I'm Client 1
# Message of Server sending: Hi Client 1
# Shutdown Client? (y/n): y
# ====================================
# open("source/chap_6/6-7_client2.py")

# Console:
# Client 2 send a message to server: Hello Server, I'm Client 2
# Message of Server sending: Yo Client 2
# Shutdown Client? (y/n): y

# %% [markdown]
# Lab 6-8

# %%
# Server
# open("source/chap_6/6-8_server.py")

# Console:
# Listen to the signal from the port 8000...
# 127.0.0.1 - - [24/Feb/2026 21:29:59] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Feb/2026 21:30:08] "POST / HTTP/1.1" 200 -
# ====================================
# Client 1
# open("source/chap_6/6-8_client.py")

# Console:
# Square a number 
# Enter a positive interger: 10
# Square a number is: 100
# ------------------------------
# Square a number 
# Enter a positive interger: 8
# Square a number is: 64

# %% [markdown]
# Lab 6-9

# %%
# Server
# open("source/chap_6/6-9_server.py")

# Console:
# Listen to the signal from the port 8000...
# Listen to the signal from the port 8000...
# 127.0.0.1 - - [24/Feb/2026 22:14:26] "POST / HTTP/1.1" 200 -
# ====================================
# Client 1
# open("source/chap_6/6-9_client.py")

# Console:
# Merge two image 
# Enter path of first image: C:\Study\Software\Python\2.Solve\source\chap_6\2_image.png
# Enter path of second image: C:\Study\Software\Python\2.Solve\source\chap_6\5_image.png
# Show Image:
